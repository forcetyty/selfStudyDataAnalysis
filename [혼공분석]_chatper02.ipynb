# %% [markdown]
# <a href="https://colab.research.google.com/github/forcetyty/selfStudyDataAnalysis/blob/main/%5B%ED%98%BC%EA%B3%B5%EB%B6%84%EC%84%9D%5D_chatper02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #02
# ## 외부에서 데이터 가져오기
# ## 02-1 (1) API / (2) HTTP / (3) JSON / (4) XML
# ## 02-2 웹 스크래핑

# %% [markdown]
# #02-1
#
# > (1) API / (2) HTTP / (3) JSON / (4) XML
#
# (1) API : application Programming Interface
#
# 무언가를 주고 받기 위해 필요한 규약
#
# (2) HTTP : Hyper Text Transfer Protocol
#
# 문자 전송을 위한 약속
#
# (3) JSON : JavaScript Object Notation
#
# 자바스크립트 객체 표기법
#
# (4) XML : eXtensible Markup Language
#
# 확장된 마크업 언어 표기법
#
# ---
# 이해하기 위한 부록 </br>
# HTML : Hypertext Markup Language
#
# 문자 표기 언어 - 마크업(Markup) 이라 불리 태그(tag)를 사용

# %% [markdown]
# #파이썬에서 JSON 데이터 다루기

# %%
# 파이썬에서 JSON 데이터 다루기
# {"key":"value"} 형태의 데이터 포맷

d = {"name":"혼자 공부하는 데이터 분석"}
print(d['name'])
# Out:
# 혼자 공부하는 데이터 분석

# %%
# json.dumps() 함수
# 파이썬 객체를 JSON 문자열로 변환
# resure_ascii = False 사용 이유
# json.dumps() 함수는 아스키 문자 외의 다른 무자를 16진수로 출력하기 때문에 한글이 잘 표현안됨
# 따라서 한글 표기를 위해 사용함.

import json
d = {"name":"혼자 공부하는 데이터 분석"}
d_str = json.dumps(d,ensure_ascii=False)

# type 함수는 데이터 타입을 확인 할 수 있음
print(type(d_str))
# Out:
# <class 'str'>

# %%
# json.loads() 함수
# JSON 문자열을 파이썬 객체로 변환
# 파이썬 객체를 바로 전송하지 않는 이유
# 웹 기반 API 통신 방식인 HTTP 가 텍스트 기반이기 때문에 객체를 HTTP 를 통해 전송할때 직렬화(serialization)이 필요
# 데이터를 받고 나서는 실행 가능하도록 역직렬화(deserialization)

import json
d = {"name":"혼자 공부하는 데이터 분석"}
d_str = json.dumps(d,ensure_ascii=False)

d2 = json.loads(d_str)
print(d2['name'])

# type 함수는 데이터 타입을 확인 할 수 있음
print(type(d2))
# Out:
# 혼자 공부하는 데이터 분석
# <class 'dict'>

# %%
import json
d3 = json.loads('{"name":"혼자 공부하는 데이터 분석", "author":"박해선", "year":2022}')

print(d3['name'])
print(d3['author'])
print(d3['year'])
# Out:
# 혼자 공부하는 데이터 분석
# 박해선
# 2022

# %%
# JSON - 특정 key 값에 다중 Value 처리하기

import json
d3 = json.loads('{"name":"혼자 공부하는 데이터 분석", "author":["박해선","홍길동"], "year":2022}')

# JSON 문자열을 파이썬 딕셔너리로 변환후 리스트의 두번째 항목을 출력
print(d3['author'][1])
# Out:
# 홍길동

# %%
#  다중 JSON 객체 처리하기

import json
d4_str = """
[
  {"name":"혼자 공부하는 데이터 분석", "author":"박해선", "year":"2022"},
  {"name":"혼자 공부하는 데이터 머신러닝+딥러닝", "author":"박해선", "year":"2020"}
]
"""
# JSON 배열은 파이썬 리스트로 변환되어 출력됨
d4 = json.loads(d4_str)
print(d4[0]['name'])
# Out:
# 혼자 공부하는 데이터 분석

# %%
# read_json 함수
# JSON 문자열을 데이터프레임으로 변함 (문자열을 데이터프레임으로 변환)

from io import StringIO
import pandas as pd

import json

d4_str = """
[
  {"name":"혼자 공부하는 데이터 분석", "author":"박해선", "year":"2022"},
  {"name":"혼자 공부하는 데이터 머신러닝+딥러닝", "author":"박해선", "year":"2020"}
]
"""

# 판다스 2.1 부터는 read_json()함수와 read_xml()함수에 파일 경로나 파일 객체를 전달해야 하며, 원시 문자열을 넣으면 경고가 발생
# 이런 경우, StringIO 클래스로 감싸면 문자영을 파일 객체 처럼 다룰 수 있음
pd.read_json(StringIO(d4_str))
# Out:
#                    name author  year
# 0        혼자 공부하는 데이터 분석    박해선  2022
# 1  혼자 공부하는 데이터 머신러닝+딥러닝    박해선  2020

# %%
# read_json 함수
# JSON 문자열을 데이터프레임으로 변함 (문자열을 데이터프레임으로 변환)

from io import StringIO
import pandas as pd

import json

d4_str = """
[
  {"name":"혼자 공부하는 데이터 분석", "author":"박해선", "year":"2022"},
  {"name":"혼자 공부하는 데이터 머신러닝+딥러닝", "author":"박해선", "year":"2020"}
]
"""
d4 = json.loads(d4_str)

pd.DataFrame(d4)
# Out:
#                    name author  year
# 0        혼자 공부하는 데이터 분석    박해선  2022
# 1  혼자 공부하는 데이터 머신러닝+딥러닝    박해선  2020

# %% [markdown]
# #파이썬에서 XML 데이터 다루기

# %%
# xml.etree.ElementTree 모듈의 fromstring() 함수를 이용하여 문자영을 파이썬 객체로 변환

import xml.etree.ElementTree as et

x_str = """
<book>
  <name>혼자 공부하는 데이터 분석</name>
  <author>박해선</author>
  <year>2022</year>
</book>
"""

# fromstring() 함수가 반환하는 객체는 단순한 파이썬 객체가 아니라
# ElementTree 모듈 아래에 정의된 Element 클래스의 객체
book = et.fromstring(x_str)

print(type(book))
print(book.tag)
# Out:
# <class 'xml.etree.ElementTree.Element'>
# book

# %%
# findtext() 메소드
# 자식 엘리먼트 확인 하기

import xml.etree.ElementTree as et

x_str = """
<book>
  <name>혼자 공부하는 데이터 분석</name>
  <author>박해선</author>
  <year>2022</year>
</book>
"""

# fromstring() 함수가 반환하는 객체는 단순한 파이썬 객체가 아니라
# ElementTree 모듈 아래에 정의된 Element 클래스의 객체
book = et.fromstring(x_str)

book_childs = list(book)  # 리스트로 변환할 때는 list() 함수를 사용

print(book_childs)

# book_childs 리스트 각 항목을 name, author, year 변수에 할당하고 text 속성으로 엘리먼트에 있는 텍스트 출력
# book_childs 리스트에 속성값에 접근

# 단점, XML은 자식 엘리먼트 순서가 항상 일정하다는 것을 보장 하지 않음
name, author, year = book_childs
print(name.text)
print(author.text)
print(year.text)
# Out:
# [<Element 'name' at 0x7accd9274e00>, <Element 'author' at 0x7accd9274a40>, <Element 'year' at 0x7accd9277c40>]
# 혼자 공부하는 데이터 분석
# 박해선
# 2022

# %%
# findtext() 메소드
# 자식 엘리먼트 확인 하기

import xml.etree.ElementTree as et

x_str = """
<book>
  <name>혼자 공부하는 데이터 분석</name>
  <author>박해선</author>
  <year>2022</year>
</book>
"""

# fromstring() 함수가 반환하는 객체는 단순한 파이썬 객체가 아니라
# ElementTree 모듈 아래에 정의된 Element 클래스의 객체
book = et.fromstring(x_str)

book_childs = list(book)  # 리스트로 변환할 때는 list() 함수를 사용

print(book_childs)

# book_childs 리스트 각 항목을 name, author, year 변수에 할당하고 text 속성으로 엘리먼트에 있는 텍스트 출력
# book_childs 리스트에 속성값에 접근

# (1)
# 단점, XML은 자식 엘리먼트 순서가 항상 일정하다는 것을 보장 하지 않음
# name, author, year = book_childs
# print(name.text)
# print(author.text)
# print(year.text)

# findtext() 메소드를 사용하면 해당 자식 엘리먼트를 탐색하여 자동으로 텍스트르 반환할 수 있음
# (1)의 방법 보다 더 정확하고 안전하게 원하는 값을 가져 올 수 있음
name = book.findtext('name')
author = book.findtext('author')
year = book.findtext('year')

print(name)
print(author)
print(year)
# Out:
# [<Element 'name' at 0x7accd90b1940>, <Element 'author' at 0x7accd90b1d00>, <Element 'year' at 0x7accd90b1cb0>]
# 혼자 공부하는 데이터 분석
# 박해선
# 2022

# %%
# findtext() 메소드
# 자식 엘리먼트 확인 하기

import xml.etree.ElementTree as et

x2_str = """
<books>
  <book>
    <name>혼자 공부하는 데이터 분석</name>
    <author>박해선</author>
    <year>2022</year>
  </book>
  <book>
    <name>혼자 공부하는 머시러닝+딥러닝</name>
    <author>박해선</author>
    <year>2020</year>
  </book>
</books>
"""

books = et.fromstring(x2_str)
print(books.tag)
# Out:
# books

# %%
# findall() 메소드와 for 문

import xml.etree.ElementTree as et

x2_str = """
<books>
  <book>
    <name>혼자 공부하는 데이터 분석</name>
    <author>박해선</author>
    <year>2022</year>
  </book>
  <book>
    <name>혼자 공부하는 머시러닝+딥러닝</name>
    <author>박해선</author>
    <year>2020</year>
  </book>
</books>
"""

# books 객체에 있는 tag 속성에 접근하여 출력
# for문을 통해 순회하며 books 객체를 출력함
for book in books.findall('book'):
  name = book.findtext('name')
  author = book.findtext('author')
  year = book.findtext('year')

print(name)
print(author)
print(year)

# xml을 판다스로 출력
# pd.read_xml(x2_str)
# Out:
# 혼자 공부하는 머시러닝+딥러닝
# 박해선
# 2020

# %% [markdown]
# # JSON과 XML 정리
# - JSON의 경우 API에서 전달한 텍스트를 json.loads() 함수를 사용해 파이썬 객체로 바꾸어 내용 추출
# - XML은 xml.etree.ElementTree 모듈에 있는 fromstring() 함수를 사용하여 </br>
# 부모 엘리멘트를 얻고,findall() 메소드로 자식 엘리멘트에 담긴 텍스트를 추출 가능

# %% [markdown]
# # Get 방식 / Post 방식
# Get 방식 : URL의 끝에 `?`를 붙이고, 변수명1=값1&변수명2=값2 와 같은 형식으로 데이터를 추가하여 전송
# Post 방식 : HTTP 요청의 본문(body)에 데이터를 담아 전송

# %%
# requests 패키지
# 파이썬으로 API 호출하기

# 도서관 정보나루 API 키
# ULR은 HTTP GET 방식으로 파라미터 값을 전달
import requests
url = "http://data4library.kr/api/loanItemSrch?format=json&startDt=2021-04-01&endDt=2021-04-30&authKey=0c05da9b04d517e73f35967f11058b87e3aac8aec2b503adbc8d3b8c5e057d77"

r = requests.get(url)

#json 메소드는 웹서버로 받은 JSON 문자열을 파이썬 객체로 변환하여 반환됨
data = r.json()
print(data)

# JSON 데이터 포맷에 맞게 출력
data
# Out:
# {'response': {'request': {'startDt': '2021-04-01', 'endDt': '2021-04-30', 'pageNo': 1, 'pageSize': 200}, 'resultNum': 200, 'numFound': 5000, 'docs': [{'doc': {'no': 1, 'ranking': '1', 'bookname': '달러구트 꿈 백화점 :주문하신 꿈은 매진입니다 ', 'authors': '지은이: 이미예', 'publisher': '팩토리나인', 'publication_year': '2020', 'isbn13': '9791165341909', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.7', 'class_nm': '문학 > 한국문학 > 소설', 'bookImageURL': 'https://image.aladin.co.kr/product/24512/70/cover/k392630952_1.jpg', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=5707051', 'loan_count': '2845'}}, {'doc': {'no': 2, 'ranking': '2', 'bookname': '아몬드 :손원평 장편소설 ', 'authors': '지은이: 손원평', 'publisher': '창비', 'publication_year': '2017', 'isbn13': '9788936434267', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.7', 'class_nm': '문학 > 한국문학 > 소설', 'bookImageURL': 'http://image.aladin.co.kr/product/16839/4/cover/k492534773_1.jpg', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=3423096', 'loan_count': '2806
# ...

# %%
# requests 패키지
# 파이썬으로 API 호출하기

# 도서관 정보나루 API 키
# ULR은 HTTP GET 방식으로 파라미터 값을 전달
import requests
url = "http://data4library.kr/api/loanItemSrch?format=json&startDt=2021-04-01&endDt=2021-04-30&authKey=0c05da9b04d517e73f35967f11058b87e3aac8aec2b503adbc8d3b8c5e057d77"

r = requests.get(url)

#json 메소드는 웹서버로 받은 JSON 문자열을 파이썬 객체로 변환하여 반환됨
data = r.json()

# doc 키에 매핑된 딕셔너리를 추출한 뒤 빈 리스트에 추가
books = []
for d in data['response']['docs']:
  books.append(d['doc'])

# 파이썬의 리스트 내포로 만드는 방법
#books = [d['doc'] for d in data['response']['docs']]

books
# Out:
# [{'no': 1,
#   'ranking': '1',
#   'bookname': '달러구트 꿈 백화점 :주문하신 꿈은 매진입니다 ',
#   'authors': '지은이: 이미예',
#   'publisher': '팩토리나인',
#   'publication_year': '2020',
#   'isbn13': '9791165341909',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'bookImageURL': 'https://image.aladin.co.kr/product/24512/70/cover/k392630952_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5707051',
#   'loan_count': '2845'},
#  {'no': 2,
#   'ranking': '2',
#   'bookname': '아몬드 :손원평 장편소설 ',
#   'authors': '지은이: 손원평',
#   'publisher': '창비',
#   'publication_year': '2017',
#   'isbn13': '9788936434267',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'bookImageURL': 'http://image.aladin.co.kr/product/16839/4/cover/k492534773_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3423096',
#   'loan_count': '2806'},
#  {'no': 3,
#   'ranking': '3',
# ...

# %%
# 판다스 DataFrame 클래스에 리스트 넘기기
# requests 패키지
# 파이썬으로 API 호출하기

# 도서관 정보나루 API 키
# ULR은 HTTP GET 방식으로 파라미터 값을 전달
import requests
import pandas as pd

url = "http://data4library.kr/api/loanItemSrch?format=json&startDt=2021-04-01&endDt=2021-04-30&authKey=0c05da9b04d517e73f35967f11058b87e3aac8aec2b503adbc8d3b8c5e057d77"

r = requests.get(url)

#json 메소드는 웹서버로 받은 JSON 문자열을 파이썬 객체로 변환하여 반환됨
data = r.json()

# doc 키에 매핑된 딕셔너리를 추출한 뒤 빈 리스트에 추가
books = []
for d in data['response']['docs']:
  books.append(d['doc'])

# 파이썬의 리스트 내포로 만드는 방법
#books = [d['doc'] for d in data['response']['docs']]

books_df = pd.DataFrame(books)
books_df
# Out:
#       no ranking                                          bookname  \
# 0      1       1                        달러구트 꿈 백화점 :주문하신 꿈은 매진입니다
# 1      2       2                                    아몬드 :손원평 장편소설
# 2      3       3                                    (추리 천재) 엉덩이 탐정
# 3      4       4                                    (추리 천재) 엉덩이 탐정
# 4      5       5                                    (추리 천재) 엉덩이 탐정
# ..   ...     ...                                               ...
# 195  196     196                                            소원 떡집
# 196  197     196                                          불만이 있어요
# 197  198     198  수학 잘하는 아이는 이렇게 공부합니다 :수학이 어려운 엄마를 위한 전략적 학습 로드맵
# 198  199     199                  부의 대이동 :달러와 금의 흐름으로 읽는 미래 투자 전략
# 199  200     200                                          놓지 마 과학!
#
#                    authors      publisher publication_year         isbn13  \
# 0                 지은이: 이미예          팩토리나인             2020  9791165341909
# ...

# %%
# 판다스 DataFrame 클래스에 리스트 넘기기
# requests 패키지
# 파이썬으로 API 호출하기

# 도서관 정보나루 API 키
# ULR은 HTTP GET 방식으로 파라미터 값을 전달
import requests
import pandas as pd

url = "http://data4library.kr/api/loanItemSrch?format=json&startDt=2021-04-01&endDt=2021-04-30&authKey=0c05da9b04d517e73f35967f11058b87e3aac8aec2b503adbc8d3b8c5e057d77"

r = requests.get(url)

#json 메소드는 웹서버로 받은 JSON 문자열을 파이썬 객체로 변환하여 반환됨
data = r.json()

# doc 키에 매핑된 딕셔너리를 추출한 뒤 빈 리스트에 추가
books = []
for d in data['response']['docs']:
  books.append(d['doc'])

# 파이썬의 리스트 내포로 만드는 방법
#books = [d['doc'] for d in data['response']['docs']]

books_df = pd.DataFrame(books)
books_df

# books_df 의 내용을 JSON으로 변환하여 저장
# to_json 메소드는 유니코드를 16진수로 저장하기 때문에 한글이 제대로 안타날수 있음
# 따라서, force_ascii=False 로 설정
books_df.to_json('20s_best_book.json', force_ascii=False)

# %% [markdown]
# # 실무 Tip
# API 방식을 이용할 때 데이터 형식이 예기치 못하게 변경 될 가능성이 있다.</br>
# 따라서, 데이터 수집 프로그램을 작성하여 정지적으로 데이터를 가져오면서 API 호출에 오류가 나타나지</br>
# 않는지 체크가 필요하다.
#
# ## key Point
# API : 프로그램 간 데이터를 전달하기 위해 정한 규칙 </br>
# HTTP : 웹에서 데이터를 주고받기 위한 프로토콜 </br>
# JSON : Javascript로 표기되는 데이터 포맷 </br>
# XML: 확장형 마크업 언어 </br>
#
# ## 기억!!!
# json.dumps() : 파이썬 객체를 JSON 문자열로 변환
# json.loads() : JSON 문자열을 파이썬 객체로 변환
# pandas.read_json() : JSON 문자열을 판다스 시리즈나 데이터프레임으로 변환
# xml.etree.ElementTree.fromstring() : XML 문자열을 분석하여 xml.etree.ElementTree.Element </br> 클래스 객체를 반환 </br>
# xml.etree.ElementTree.Element.findtext() : 지정한 태그 이름과 맞는 첫 번째 자식 엘리먼트의 텍스트를 반환 </br>
# xml.etree.ElementTree.Element.findall() : 지정한 태그 이름과 맞는 모든 자식 엘리먼트 반환
# </br>
# requests.get() : HTTP GET 방식으로 URL을 호출하고 requests.Response 객체 반환</br>
# requests.Response.json() : 응답받은 JSON 문자열을 파이썬 객체로 변환 </br>

# %% [markdown]
# #02-2
# > 웹 스크래핑 </br>
# 프로그램으로 웹사이트의 페이지를 옴겨 가며 데이터를 추출하는 작업을 </br>
# 웹 스크래핑(web scraping) / 웹 크롤링 (web crawling) 이라고 함</br>

# %%
import gdown

# 02-1에서 만들 데이터를 활용
gdown.download('https://bit.ly/3q9SZix', '20s_best_book.json', quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3q9SZix
# To: /content/20s_best_book.json
# 100%|██████████| 92.9k/92.9k [00:00<00:00, 50.7MB/s]
# '20s_best_book.json'

# %%
import gdown
import pandas as pd

# 02-1에서 만들 데이터를 활용
gdown.download('https://bit.ly/3q9SZix', '20s_best_book.json', quiet=False)
books_df = pd.read_json('20s_best_book.json')
books_df.head()
# Out:
# Downloading...
# From: https://bit.ly/3q9SZix
# To: /content/20s_best_book.json
# 100%|██████████| 92.9k/92.9k [00:00<00:00, 61.4MB/s]
#    no  ranking                     bookname   authors publisher  \
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 1   2        2         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예     팩토리나인
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑        난다
# 3   4        4           시선으로부터, :정세랑 장편소설   지은이: 정세랑      문학동네
# 4   5        5               아몬드 :손원평 장편소설   지은이: 손원평        창비
#
#   publication_year         isbn13 addition_symbol vol  class_no  \
# 0             2019  9791190090018           03810         813.7
# 1             2020  9791165341909           03810         813.7
# 2             2019  9791188862290           03810         813.7
# 3             2020  9788954672214           03810         813.7
# 4             2017  9788936434267           03810         813.7
#
#          class_nm  loan_count  \
# ...

# %%
import gdown
import pandas as pd

# 02-1에서 만들 데이터를 활용
gdown.download('https://bit.ly/3q9SZix', '20s_best_book.json', quiet=False)
books_df = pd.read_json('20s_best_book.json')

# 특정 속성만 출력하기
books = books_df[['no', 'ranking', 'bookname', 'authors', 'publisher',
                  'publication_year','isbn13']]
books.head()
# Out:
# Downloading...
# From: https://bit.ly/3q9SZix
# To: /content/20s_best_book.json
# 100%|██████████| 92.9k/92.9k [00:00<00:00, 51.8MB/s]
#    no  ranking                     bookname   authors publisher  \
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 1   2        2         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예     팩토리나인
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑        난다
# 3   4        4           시선으로부터, :정세랑 장편소설   지은이: 정세랑      문학동네
# 4   5        5               아몬드 :손원평 장편소설   지은이: 손원평        창비
#
#   publication_year         isbn13
# 0             2019  9791190090018
# 1             2020  9791165341909
# 2             2019  9791188862290
# 3             2020  9788954672214
# 4             2017  9788936434267

# %%
import gdown
import pandas as pd

# 02-1에서 만들 데이터를 활용
gdown.download('https://bit.ly/3q9SZix', '20s_best_book.json', quiet=False)
books_df = pd.read_json('20s_best_book.json')

# 특정 속성만 출력하기
# books = books_df[['no', 'ranking', 'bookname', 'authors', 'publisher',
#                  'publication_year','isbn13']]
# books_df.head()

# 출력해야 할 열 속성이 많다면 제안사항이 발생한다
# 판다스가 제공하는 loc() 메서드를 사용하면 원하는 행과 열을 조금 더 쉽게 선택 할 수 있다.
# books_df.loc[[0,1], ['bookname', 'authors']]

# loc에서는 슬라이스 연산자(:) 사용이 가능
books_df.loc[[0,1], 'bookname':'authors']

# 열 속성을 일일이 나열하는 것보다 loc 메소드와 슬라이스 연산자를 사용하여 출력하는 것이 효율적
# Out:
# Downloading...
# From: https://bit.ly/3q9SZix
# To: /content/20s_best_book.json
# 100%|██████████| 92.9k/92.9k [00:00<00:00, 61.7MB/s]
#                       bookname   authors
# 0  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽
# 1         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예

# %%
# HTML 가져오기 : requests.get() 함수
import requests
isbn = 9791190090018 # '우리가 빛의 속도로 갈 수 없다면'의 ISBN

# 책과 250714 기준의 URL의 차이가 있음
url = 'https://www.yes24.com/product/search?domain=BOOK&query={}'
r = requests.get(url.format(isbn))
print(r.text)
# Out:
# 	<!DOCTYPE html >
# 	<html lang="ko">
#
# <head>
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
#     <meta name="viewport" content="width=1170" />
#
#     <title> 9791190090018 - 예스24</title>
#
# 	<meta name="title" content="예스24" />
# 	<meta name="description" content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" />
# 	<meta name="keywords" content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘, 리센스, 예스24 도서용품, 친환경 PB 브랜드, 사은품, 굿즈" />
#
#
# ...

# %%
# HTML에서 데이터 추출하기 : 뷰티플수프
# HTML 에서 데이터 추출하는 툴
# (1) 뷰티블수프 Beautiful Soup
# (2) 스크래피 Scrapy

# HTML 가져오기 : requests.get() 함수
import requests
isbn = 9791190090018 # '우리가 빛의 속도로 갈 수 없다면'의 ISBN

url = 'https://www.yes24.com/product/search?domain=BOOK&query={}'
r = requests.get(url.format(isbn))

from bs4 import BeautifulSoup

# 첫번째 매개변수 : 파싱항 HTML 문서
# 두번째 매개변수 : 파싱에 사용할 파서 parser
soup = BeautifulSoup(r.text, 'html.parser')

# Tip
# html.parser는 파이썬에 기본 내장된 HTML 파서.
# 뷰티플수프에 설치되어 있는 lxml은 HTML 표준을 엄격히 검사하기 때문에 파싱에 실패 할 수 있음.

# %%
# HTML에서 데이터 추출하기 : 뷰티플수프
# HTML 에서 데이터 추출하는 툴
# (1) 뷰티블수프 Beautiful Soup
# (2) 스크래피 Scrapy

# HTML 가져오기 : requests.get() 함수
import requests
from bs4 import BeautifulSoup
isbn = 9791190090018 # '우리가 빛의 속도로 갈 수 없다면'의 ISBN


url = 'https://www.yes24.com/product/search?domain=BOOK&query={}'
r = requests.get(url.format(isbn))

# 첫번째 매개변수 : 파싱항 HTML 문서
# 두번째 매개변수 : 파싱에 사용할 파서 parser
soup = BeautifulSoup(r.text, 'html.parser')

# Tip
# html.parser는 파이썬에 기본 내장된 HTML 파서.
# 뷰티플수프에 설치되어 있는 lxml은 HTML 표준을 엄격히 검사하기 때문에 파싱에 실패 할 수 있음.

# 태그 위치 찾기 find() 메서드
prd_link = soup.find('a', attrs={'class':'gd_name'})
print(prd_link)
print(prd_link['href'])
# Out:
# <a class="gd_name" href="/product/goods/74261416" onclick="wiseLogV2('S', '101_005_003_001', ''); setGoodsClickExtraCodeHub('032', '9791190090018', '74261416', '0',this);">우리가 빛의 속도로 갈 수 없다면</a>
# /product/goods/74261416

# %%
# HTML에서 데이터 추출하기 : 뷰티플수프
# HTML 에서 데이터 추출하는 툴
# (1) 뷰티블수프 Beautiful Soup
# (2) 스크래피 Scrapy

# HTML 가져오기 : requests.get() 함수
import requests
from bs4 import BeautifulSoup
isbn = 9791190090018 # '우리가 빛의 속도로 갈 수 없다면'의 ISBN


url = 'https://www.yes24.com/product/search?domain=BOOK&query={}'
r = requests.get(url.format(isbn))

# 첫번째 매개변수 : 파싱항 HTML 문서
# 두번째 매개변수 : 파싱에 사용할 파서 parser
soup = BeautifulSoup(r.text, 'html.parser')

# Tip
# html.parser는 파이썬에 기본 내장된 HTML 파서.
# 뷰티플수프에 설치되어 있는 lxml은 HTML 표준을 엄격히 검사하기 때문에 파싱에 실패 할 수 있음.

# 태그 위치 찾기 find() 메서드
prd_link = soup.find('a', attrs={'class':'gd_name'})
#print(prd_link)
#print(prd_link['href'])

# 도서 상세 페이지 HTML 가져오기
# <a> 태그의 상세페이지 이동
url = 'http://www.yes24.com'+prd_link['href']
r = requests.get(url)

# 내용 확인
# print(r.text)

soup = BeautifulSoup(r.text, 'html.parser')
prd_detail = soup.find('div', attrs={'id':'infoset_specific'})

# table 태그로 찾기
# prd_detail = soup.find('table', attrs={'class':'tb_nor tb_vertical'})
print(prd_detail)
# Out:
# <div class="gd_infoSet infoSet_noLine" id="infoset_specific">
# <div class="tm_infoSet">
# <h4 class="tit_txt">품목정보</h4>
# </div>
# <div class="infoSetCont_wrap">
# <div class="yesTb">
# <table class="tb_nor tb_vertical" summary="품목정보 국내도서, 외국도서 " width="100%">
# <caption>품목정보</caption>
# <colgroup>
# <col width="170"/>
# <col width="*"/>
# </colgroup>
# <tbody class="b_size">
# <tr>
# <th class="txt" scope="row">발행일</th>
# <td class="txt lastCol">2019년 06월 24일</td>
# </tr>
# <tr>
# <th class="txt" scope="row">쪽수, 무게, 크기</th>
# <td class="txt lastCol">344쪽 | 496g | 130*198*30mm</td>
# </tr>
# <tr>
# <th class="txt" scope="row">ISBN13</th>
# <td class="txt lastCol">9791190090018</td>
# </tr>
# <tr>
# <th class="txt" scope="row">ISBN10</th>
# <td class="txt lastCol">1190090015</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <script type="text/javascript">
#         if ($("#infoset_specific table tbody tr").length == 0) {
#             $("#infoset_specific").remove();
# ...

# %%
# HTML에서 데이터 추출하기 : 뷰티플수프
# HTML 에서 데이터 추출하는 툴
# (1) 뷰티블수프 Beautiful Soup
# (2) 스크래피 Scrapy

# HTML 가져오기 : requests.get() 함수
import requests
from bs4 import BeautifulSoup
isbn = 9791190090018 # '우리가 빛의 속도로 갈 수 없다면'의 ISBN


url = 'https://www.yes24.com/product/search?domain=BOOK&query={}'
r = requests.get(url.format(isbn))

# 첫번째 매개변수 : 파싱항 HTML 문서
# 두번째 매개변수 : 파싱에 사용할 파서 parser
soup = BeautifulSoup(r.text, 'html.parser')

# Tip
# html.parser는 파이썬에 기본 내장된 HTML 파서.
# 뷰티플수프에 설치되어 있는 lxml은 HTML 표준을 엄격히 검사하기 때문에 파싱에 실패 할 수 있음.

# 태그 위치 찾기 find() 메서드
prd_link = soup.find('a', attrs={'class':'gd_name'})
#print(prd_link)
#print(prd_link['href'])

# 도서 상세 페이지 HTML 가져오기
# <a> 태그의 상세페이지 이동
url = 'http://www.yes24.com'+prd_link['href']
r = requests.get(url)

# 내용 확인
# print(r.text)

soup = BeautifulSoup(r.text, 'html.parser')
prd_detail = soup.find('div', attrs={'id':'infoset_specific'})

# table 태그로 찾기
# prd_detail = soup.find('table', attrs={'class':'tb_nor tb_vertical'})

# print(prd_detail)

# 테이블 태그를 리스트로 가져오기 : find_all() 메서드
# 특정 HTML 태그를 모두 찾아서 리스트로 반환

prd_tr_list = prd_detail.find_all('tr')
print(prd_tr_list)
# Out:
# [<tr>
# <th class="txt" scope="row">발행일</th>
# <td class="txt lastCol">2019년 06월 24일</td>
# </tr>, <tr>
# <th class="txt" scope="row">쪽수, 무게, 크기</th>
# <td class="txt lastCol">344쪽 | 496g | 130*198*30mm</td>
# </tr>, <tr>
# <th class="txt" scope="row">ISBN13</th>
# <td class="txt lastCol">9791190090018</td>
# </tr>, <tr>
# <th class="txt" scope="row">ISBN10</th>
# <td class="txt lastCol">1190090015</td>
# </tr>]

# %%
# HTML에서 데이터 추출하기 : 뷰티플수프
# HTML 에서 데이터 추출하는 툴
# (1) 뷰티블수프 Beautiful Soup
# (2) 스크래피 Scrapy

# HTML 가져오기 : requests.get() 함수
import requests
from bs4 import BeautifulSoup
isbn = 9791190090018 # '우리가 빛의 속도로 갈 수 없다면'의 ISBN


url = 'https://www.yes24.com/product/search?domain=BOOK&query={}'
r = requests.get(url.format(isbn))

# 첫번째 매개변수 : 파싱항 HTML 문서
# 두번째 매개변수 : 파싱에 사용할 파서 parser
soup = BeautifulSoup(r.text, 'html.parser')

# Tip
# html.parser는 파이썬에 기본 내장된 HTML 파서.
# 뷰티플수프에 설치되어 있는 lxml은 HTML 표준을 엄격히 검사하기 때문에 파싱에 실패 할 수 있음.

# 태그 위치 찾기 find() 메서드
prd_link = soup.find('a', attrs={'class':'gd_name'})
#print(prd_link)
#print(prd_link['href'])

# 도서 상세 페이지 HTML 가져오기
# <a> 태그의 상세페이지 이동
url = 'http://www.yes24.com'+prd_link['href']
r = requests.get(url)

# 내용 확인
# print(r.text)

soup = BeautifulSoup(r.text, 'html.parser')
prd_detail = soup.find('div', attrs={'id':'infoset_specific'})

# table 태그로 찾기
# prd_detail = soup.find('table', attrs={'class':'tb_nor tb_vertical'})

# print(prd_detail)

# 테이블 태그를 리스트로 가져오기 : find_all() 메서드
# 특정 HTML 태그를 모두 찾아서 리스트로 반환

prd_tr_list = prd_detail.find_all('tr')
#print(prd_tr_list)

# 태그 안의 텍스트 가져오기 : get_text() 메소드
for tr in prd_tr_list:
  if tr.find('th').get_text() == '쪽수, 무게, 크기':
    page_td = tr.find('td').get_text()
    break

print(page_td)

# split() 메서드로 자르기
print(page_td.split()[0])
# Out:
# 344쪽 | 496g | 130*198*30mm
# 344쪽

# %%
# HTML에서 데이터 추출하기 : 뷰티플수프
# HTML 에서 데이터 추출하는 툴
# (1) 뷰티블수프 Beautiful Soup
# (2) 스크래피 Scrapy

# HTML 가져오기 : requests.get() 함수
import requests
from bs4 import BeautifulSoup

# 전체 도서의 쪽수 구하기
# 판다스 데이터프레임은 한 행씩 순차적으로 처리하느데 최적화 되어 있지 않음.
# 데이터프레임을 for문으로 반복하는 것은 비효율적
# 대신, 데이터프레임은 각 행 또는 각 열에 원하는 함수를 자동으로 적용해 주는 여러가지 방법을 제공

def get_page_cnt(isbn):
  # Yes24 도서 검색 페이지 URL
  url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'

  # URL에 ISBN을 넣어 HTML 획득
  r = requests.get(url.format(isbn))
  soup = BeautifulSoup(r.text, 'html.parser') #html 파싱

  #print(soup) #디버깅용

  # 검색 결과에서 해당 도서를 선택
  prd_info = soup.find('a', attrs={'class':'gd_name'})
  if prd_info == None:
    return ''

  #print(prd_info) #디버깅용

  # 도서 상세 페이지를 가져옴
  url = 'http://www.yes24.com'+prd_info['href']
  r = requests.get(url)
  soup = BeautifulSoup(r.text, 'html.parser')

  # 품목정보 <div>를 선택
  prd_detail = soup.find('div', attrs={'id':'infoset_specific'})

  # 테이블에 있는 <tr> 태그를 가져옴
  prd_tr_list = prd_detail.find_all('tr')

  # 쪽수가 들어 있는 <th>를 찾아 <td>에 담긴 값을 반환
  for tr in prd_tr_list:
    if tr.find('th').get_text() == '쪽수, 무게, 크기':
      return tr.find('td').get_text().split()[0]
  return ''

get_page_cnt(9791190090018)
# Out:
# '344쪽'

# %%
# HTML에서 데이터 추출하기 : 뷰티플수프
# HTML 에서 데이터 추출하는 툴
# (1) 뷰티블수프 Beautiful Soup
# (2) 스크래피 Scrapy

# HTML 가져오기 : requests.get() 함수
import requests
from bs4 import BeautifulSoup

import gdown
import pandas as pd

# 02-1에서 만들 데이터를 활용
gdown.download('https://bit.ly/3q9SZix', '20s_best_book.json', quiet=False)
books_df = pd.read_json('20s_best_book.json')

# 특정 속성만 출력하기
# books = books_df[['no', 'ranking', 'bookname', 'authors', 'publisher',
#                  'publication_year','isbn13']]
# books_df.head()

# 출력해야 할 열 속성이 많다면 제안사항이 발생한다
# 판다스가 제공하는 loc() 메서드를 사용하면 원하는 행과 열을 조금 더 쉽게 선택 할 수 있다.
# books_df.loc[[0,1], ['bookname', 'authors']]

# loc에서는 슬라이스 연산자(:) 사용이 가능
# books_df.loc[[0,1], 'bookname':'authors']

# 열 속성을 일일이 나열하는 것보다 loc 메소드와 슬라이스 연산자를 사용하여 출력하는 것이 효율적

#####################################

# 전체 도서의 쪽수 구하기
# 판다스 데이터프레임은 한 행씩 순차적으로 처리하느데 최적화 되어 있지 않음.
# 데이터프레임을 for문으로 반복하는 것은 비효율적
# 대신, 데이터프레임은 각 행 또는 각 열에 원하는 함수를 자동으로 적용해 주는 여러가지 방법을 제공

def get_page_cnt(isbn):
  # Yes24 도서 검색 페이지 URL
  url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'

  # URL에 ISBN을 넣어 HTML 획득
  r = requests.get(url.format(isbn))
  soup = BeautifulSoup(r.text, 'html.parser') #html 파싱

  #print(soup) #디버깅용

  # 검색 결과에서 해당 도서를 선택
  prd_info = soup.find('a', attrs={'class':'gd_name'})
  if prd_info == None:
    return ''

  print(prd_info) #디버깅용

  # 도서 상세 페이지를 가져옴
  url = 'http://www.yes24.com'+prd_info['href']
  r = requests.get(url)
  soup = BeautifulSoup(r.text, 'html.parser')

  # 품목정보 <div>를 선택
  prd_detail = soup.find('div', attrs={'id':'infoset_specific'})

  # 테이블에 있는 <tr> 태그를 가져옴
  prd_tr_list = prd_detail.find_all('tr')

  # 쪽수가 들어 있는 <th>를 찾아 <td>에 담긴 값을 반환
  for tr in prd_tr_list:
    if tr.find('th').get_text() == '쪽수, 무게, 크기':
      return tr.find('td').get_text().split()[0]
  return ''

#get_page_cnt(9791190090018)

# 데이터프레임 행 혹은 열에 함수 적용하기 : apply() 메서드
top10_books = books.head(10)

def get_page_cnt2(row):
    isbn = row['isbn13']
    return get_page_cnt(isbn)

page_count = top10_books.apply(get_page_cnt2, axis=1)
print(page_count)

# def 함수를 두번 만들지 않고
# 한번만 만들수 있는 방법 = 람다
# page_count = top10_books.apply(lambda row: get_page_cnt(row['isbn13']), axis=1)
# Out:
# Downloading...
# From: https://bit.ly/3q9SZix
# To: /content/20s_best_book.json
# 100%|██████████| 92.9k/92.9k [00:00<00:00, 62.5MB/s]
# <a class="gd_name" href="/product/goods/74261416" onclick="wiseLogV2('S', '101_005_003_001', ''); setGoodsClickExtraCodeHub('032', '9791190090018', '74261416', '0',this);">우리가 빛의 속도로 갈 수 없다면</a>
# <a class="gd_name" href="/product/goods/91065309" onclick="wiseLogV2('S', '101_005_003_001', ''); setGoodsClickExtraCodeHub('032', '9791165341909', '91065309', '0',this);">달러구트 꿈 백화점</a>
# <a class="gd_name" href="/product/goods/76106687" onclick="wiseLogV2('S', '101_005_003_001', ''); setGoodsClickExtraCodeHub('032', '9791188862290', '76106687', '0',this);">지구에서 한아뿐</a>
# <a class="gd_name" href="/product/goods/90367403" onclick="wiseLogV2('S', '101_005_003_001', ''); setGoodsClickExtraCodeHub('032', '9788954672214', '90367403', '0',this);">시선으로부터,</a>
# ...

# %%
# HTML에서 데이터 추출하기 : 뷰티플수프
# HTML 에서 데이터 추출하는 툴
# (1) 뷰티블수프 Beautiful Soup
# (2) 스크래피 Scrapy

# HTML 가져오기 : requests.get() 함수
import requests
from bs4 import BeautifulSoup

import gdown
import pandas as pd

# 02-1에서 만들 데이터를 활용
gdown.download('https://bit.ly/3q9SZix', '20s_best_book.json', quiet=False)
books_df = pd.read_json('20s_best_book.json')

# 특정 속성만 출력하기
# books = books_df[['no', 'ranking', 'bookname', 'authors', 'publisher',
#                  'publication_year','isbn13']]
# books_df.head()

# 출력해야 할 열 속성이 많다면 제안사항이 발생한다
# 판다스가 제공하는 loc() 메서드를 사용하면 원하는 행과 열을 조금 더 쉽게 선택 할 수 있다.
# books_df.loc[[0,1], ['bookname', 'authors']]

# loc에서는 슬라이스 연산자(:) 사용이 가능
# books_df.loc[[0,1], 'bookname':'authors']

# 열 속성을 일일이 나열하는 것보다 loc 메소드와 슬라이스 연산자를 사용하여 출력하는 것이 효율적

#####################################

# 전체 도서의 쪽수 구하기
# 판다스 데이터프레임은 한 행씩 순차적으로 처리하느데 최적화 되어 있지 않음.
# 데이터프레임을 for문으로 반복하는 것은 비효율적
# 대신, 데이터프레임은 각 행 또는 각 열에 원하는 함수를 자동으로 적용해 주는 여러가지 방법을 제공

def get_page_cnt(isbn):
  # Yes24 도서 검색 페이지 URL
  url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'

  # URL에 ISBN을 넣어 HTML 획득
  r = requests.get(url.format(isbn))
  soup = BeautifulSoup(r.text, 'html.parser') #html 파싱

  #print(soup) #디버깅용

  # 검색 결과에서 해당 도서를 선택
  prd_info = soup.find('a', attrs={'class':'gd_name'})
  if prd_info == None:
    return ''

  print(prd_info) #디버깅용

  # 도서 상세 페이지를 가져옴
  url = 'http://www.yes24.com'+prd_info['href']
  r = requests.get(url)
  soup = BeautifulSoup(r.text, 'html.parser')

  # 품목정보 <div>를 선택
  prd_detail = soup.find('div', attrs={'id':'infoset_specific'})

  # 테이블에 있는 <tr> 태그를 가져옴
  prd_tr_list = prd_detail.find_all('tr')

  # 쪽수가 들어 있는 <th>를 찾아 <td>에 담긴 값을 반환
  for tr in prd_tr_list:
    if tr.find('th').get_text() == '쪽수, 무게, 크기':
      return tr.find('td').get_text().split()[0]
  return ''

#get_page_cnt(9791190090018)

# 데이터프레임 행 혹은 열에 함수 적용하기 : apply() 메서드
top10_books = books.head(10)

def get_page_cnt2(row):
    isbn = row['isbn13']
    return get_page_cnt(isbn)

page_count = top10_books.apply(get_page_cnt2, axis=1)
#print(page_count)

# def 함수를 두번 만들지 않고
# 한번만 만들수 있는 방법 = 람다
# page_count = top10_books.apply(lambda row: get_page_cnt(row['isbn13']), axis=1)


# 데이터프레임과 시리즈 합치기 : merge() 함수
page_count.name = 'page_count'
#print(page_count)

top10_with_page_count = pd.merge(top10_books, page_count,
                                left_index=True, right_index=True)
top10_with_page_count
# Out:
# Downloading...
# From: https://bit.ly/3q9SZix
# To: /content/20s_best_book.json
# 100%|██████████| 92.9k/92.9k [00:00<00:00, 65.1MB/s]
# <a class="gd_name" href="/product/goods/74261416" onclick="wiseLogV2('S', '101_005_003_001', ''); setGoodsClickExtraCodeHub('032', '9791190090018', '74261416', '0',this);">우리가 빛의 속도로 갈 수 없다면</a>
# <a class="gd_name" href="/product/goods/91065309" onclick="wiseLogV2('S', '101_005_003_001', ''); setGoodsClickExtraCodeHub('032', '9791165341909', '91065309', '0',this);">달러구트 꿈 백화점</a>
# <a class="gd_name" href="/product/goods/76106687" onclick="wiseLogV2('S', '101_005_003_001', ''); setGoodsClickExtraCodeHub('032', '9791188862290', '76106687', '0',this);">지구에서 한아뿐</a>
# <a class="gd_name" href="/product/goods/90367403" onclick="wiseLogV2('S', '101_005_003_001', ''); setGoodsClickExtraCodeHub('032', '9788954672214', '90367403', '0',this);">시선으로부터,</a>
# ...

# %% [markdown]
# # 실무 Tip
# ## 웹 스크래핑할 때 주의할 점
#
# (1) 웹사이트에서 스크래핑을 허락하였는지 확인 필요
#   robots.txt 파일에서 확인 할 수 있음
#
# (2) HTML 태그를 특정할 수 있는지 확인 필요
#   고급도구로는 Selenium과 같은 고급 도구가 있음
